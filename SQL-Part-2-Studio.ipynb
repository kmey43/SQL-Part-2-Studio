-- %% [markdown]
-- # Lesson 11: SQL Part 2 Studio
--
-- > This studio asks you to create queries using the functions from this lesson. As you work through the studio, you may need to create more than one query to return the desired answer.  For others, you may need to combine functions together in order to answer the original query.  The questions have been organized in a way to help you puzzle out the answers.
-- >
-- > Happy querying!
--
-- **The Dataset:**
--
-- > We will be working with the **BooksDB dataset** from Lesson 10.  You should already have access to it.

-- %% [markdown]
-- ## The Questions:

-- %% [markdown]
-- 1.  Create a query that returns the longest title in the dataset.  We can do this in two steps.
--
-- > A. Create a query that returns the length of the longest title.
-- >
-- > B. Create a query that uses the length you found in step A to find the longest title.

-- %%
-- Code here:
with title_lengths as (select
book_id,
isbn,
authors,
title,
len(title) as title_length
from booksDB.dbo.books)

select*
from title_lengths
WHERE title_length = (SELECT MAX(title_length) FROM title_lengths)
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.055
-- <table><tr><th>book_id</th><th>isbn</th><th>authors</th><th>title</th><th>title_length</th></tr><tr><td>6617185</td><td>1568584253</td><td>Simon Kuper, Stefan Szymanski</td><td>Soccernomics: Why England Loses, Why Germany and Brazil Win, and Why the U.S., Japan, Australia, Turkey--and Even Iraq--Are Destined to Become the Kings of the World's Most Popular Sport</td><td>186</td></tr></table>

-- %% [markdown]
-- 2.  Use what you learned in question 1 to find the shortest author name.
--
-- > A. Create a query that returns the length of the shortest author.
-- >
-- > B. Create a query that returns the shortest author's name.

-- %%
-- Code here:
with author_lengths as (select
book_id,
isbn,
authors,
title,
len(authors) as author_length
from booksDB.dbo.books)

select*
from author_lengths
WHERE  author_length = (SELECT min(author_length) FROM author_lengths)
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.055
-- <table><tr><th>book_id</th><th>isbn</th><th>authors</th><th>title</th><th>author_length</th></tr><tr><td>310146</td><td>380714752</td><td>Avi</td><td>The True Confessions of Charlotte Doyle</td><td>3</td></tr><tr><td>353342</td><td>786816589</td><td>Avi</td><td>The Cross of Lead (Crispin, #1)</td><td>3</td></tr></table>

-- %% [markdown]
-- 3\. How many titles contain the word "The"?
--
-- > A. Is there a difference between the number of titles that use "The" or "the"? No

-- %%
-- Code here:
select COUNT(title) as count_The
from BooksDB.dbo.books
where title like '%The%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.062
-- <table><tr><th>count_The</th></tr><tr><td>4702</td></tr></table>

-- %% [markdown]
-- 4.  How many authors' names _start_ with 'Z'?

-- %%
-- Code here:
select COUNT(authors) as author_z
from BooksDB.dbo.books
where authors like 'Z%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.044
-- <table><tr><th>author_z</th></tr><tr><td>11</td></tr></table>

-- %% [markdown]
-- 5\. How many books have been identified as printed in a language other than English?  There are four language codes for English: 'en', 'eng', 'en-US', and 'en-UK'.  Use LEFT to answer the question.  (Do not use the wildcard)
--
-- You might want to use one of these [comparison operators](https://docs.microsoft.com/en-us/sql/t-sql/language-elements/comparison-operators-transact-sql?view=sql-server-ver15).

-- %%
-- Code here:
select count(title) as non_english_books
from BooksDB.dbo.books
where left(language_code,2)<>'en'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.066
-- <table><tr><th>non_english_books</th></tr><tr><td>186</td></tr></table>

-- %% [markdown]
-- 6\. Retry question 5 using SUBSTRING.

-- %%
-- Code here:
select count(title) as non_english_books
from BooksDB.dbo.books
where substring(language_code,1,2)<>'en'

--SELECT SUBSTRING('SQL Tutorial', 1, 3)
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.067
-- <table><tr><th>non_english_books</th></tr><tr><td>186</td></tr></table>

-- %% [markdown]
-- 7.  Create a column that returns the title, authors, and language codes.  Concatenate these elements so that they return in the following way: title by authors in language\_code language.
--
-- > A.  Check each selected column to see where any values are NULL.  Did any of the columns contain NULL values?  If so, which one? Language code

-- %%
-- Code here:
SELECT CONCAT(title, ' by '+ authors, ' in '+ language_code + ' language') as book_auth_lang
-- title,
-- authors,
-- language_code
from BooksDB.dbo.books
-- Out:
-- (10000 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:01.153
-- <table><tr><th>book_auth_lang</th></tr><tr><td>The Hunger Games (The Hunger Games, #1) by Suzanne Collins in eng language</td></tr><tr><td>Harry Potter and the Sorcerer's Stone (Harry Potter, #1) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>Twilight (Twilight, #1) by Stephenie Meyer in en-US language</td></tr><tr><td>To Kill a Mockingbird by Harper Lee in eng language</td></tr><tr><td>The Great Gatsby by F. Scott Fitzgerald in eng language</td></tr><tr><td>The Fault in Our Stars by John Green in eng language</td></tr><tr><td>The Hobbit by J.R.R. Tolkien in en-US language</td></tr><tr><td>The Catcher in the Rye by J.D. Salinger in eng language</td></tr><tr><td>Angels &amp; Demons  (Robert Langdon, #1) by Dan Brown in en-CA language</td></tr><tr><td>Pride and Prejudice by Jane Austen in eng language</td></tr><tr><td>The Kite Runner by Khaled Hosseini in eng language</td></tr><tr><td>Divergent (Divergent, #1) by Veronica Roth in eng language</td></tr><tr><td>1984 by George Orwell, Erich Fromm, Celâl Üster in eng language</td></tr><tr><td>Animal Farm by George Orwell in eng language</td></tr><tr><td>The Diary of a Young Girl by Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-Doubleday in eng language</td></tr><tr><td>The Girl with the Dragon Tattoo (Millennium, #1) by Stieg Larsson, Reg Keeland in eng language</td></tr><tr><td>Catching Fire (The Hunger Games, #2) by Suzanne Collins in eng language</td></tr><tr><td>Harry Potter and the Prisoner of Azkaban (Harry Potter, #3) by J.K. Rowling, Mary GrandPré, Rufus Beck in eng language</td></tr><tr><td>The Fellowship of the Ring (The Lord of the Rings, #1) by J.R.R. Tolkien in eng language</td></tr><tr><td>Mockingjay (The Hunger Games, #3) by Suzanne Collins in eng language</td></tr><tr><td>Harry Potter and the Order of the Phoenix (Harry Potter, #5) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>The Lovely Bones by Alice Sebold in eng language</td></tr><tr><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>Harry Potter and the Goblet of Fire (Harry Potter, #4) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>Harry Potter and the Deathly Hallows (Harry Potter, #7) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>The Da Vinci Code (Robert Langdon, #2) by Dan Brown in eng language</td></tr><tr><td>Harry Potter and the Half-Blood Prince (Harry Potter, #6) by J.K. Rowling, Mary GrandPré in eng language</td></tr><tr><td>Lord of the Flies by William Golding in eng language</td></tr><tr><td>Romeo and Juliet by William Shakespeare, Robert           Jackson in eng language</td></tr><tr><td>Gone Girl by Gillian Flynn in eng language</td></tr><tr><td>The Help by Kathryn Stockett in eng language</td></tr><tr><td>Of Mice and Men by John Steinbeck in eng language</td></tr><tr><td>Memoirs of a Geisha by Arthur Golden in eng language</td></tr><tr><td>Fifty Shades of Grey (Fifty Shades, #1) by E.L. James in eng language</td></tr><tr><td>The Alchemist by Paulo Coelho, Alan R. Clarke in eng language</td></tr><tr><td>The Giver (The Giver, #1) by Lois Lowry in eng language</td></tr><tr><td>The Lion, the Witch, and the Wardrobe (Chronicles of Narnia, #1) by C.S. Lewis in eng language</td></tr><tr><td>The Time Traveler's Wife by Audrey Niffenegger in eng language</td></tr><tr><td>A Game of Thrones (A Song of Ice and Fire, #1) by George R.R. Martin in eng language</td></tr><tr><td>Eat, Pray, Love by Elizabeth Gilbert in eng language</td></tr><tr><td>The Lightning Thief (Percy Jackson and the Olympians, #1) by Rick Riordan in eng language</td></tr><tr><td>Little Women (Little Women, #1) by Louisa May Alcott in en-US language</td></tr><tr><td>Jane Eyre by Charlotte Brontë, Michael Mason in eng language</td></tr><tr><td>The Notebook (The Notebook, #1) by Nicholas Sparks in eng language</td></tr><tr><td>Life of Pi by Yann Martel</td></tr><tr><td>Water for Elephants by Sara Gru ...

-- %% [markdown]
-- 8.  Update the query in question 7 using COALESCE to change the language code values from NULL to 'unknown'.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:

SELECT CONCAT(title, ' by '+ authors,NULL,' in ' + language_code + ' language') book_auth_lang
-- title,
-- authors,
-- language_code
from BooksDB.dbo.books
where language_code is null
-- Out:
-- (1084 rows affected)
-- Total execution time: 00:00:00.231
-- <table><tr><th>book_auth_lang</th></tr><tr><td>Life of Pi by Yann Martel</td></tr><tr><td>The Five People You Meet in Heaven by Mitch Albom</td></tr><tr><td>A Christmas Carol by Charles Dickens</td></tr><tr><td>Carrie by Stephen King</td></tr><tr><td>The Hunt for Red October (Jack Ryan Universe, #4) by Tom Clancy</td></tr><tr><td>Where the Red Fern Grows by Wilson Rawls</td></tr><tr><td>Fried Green Tomatoes at the Whistle Stop Cafe by Fannie Flagg</td></tr><tr><td>The Three Musketeers by Alexandre Dumas</td></tr><tr><td>In Her Shoes by Jennifer Weiner</td></tr><tr><td>The Andromeda Strain by Michael Crichton</td></tr><tr><td>Needful Things by Stephen King</td></tr><tr><td>Are You There, Vodka? It's Me, Chelsea by Chelsea Handler</td></tr><tr><td>Prey by Michael Crichton</td></tr><tr><td>Mrs. Frisby and the Rats of NIMH (Rats of NIMH, #1) by Robert C. O'Brien</td></tr><tr><td>The Little House Collection (Little House, #1-9) by Laura Ingalls Wilder, Garth Williams</td></tr><tr><td>The Girls' Guide to Hunting and Fishing by Melissa Bank</td></tr><tr><td>Sh*t My Dad Says by Justin Halpern</td></tr><tr><td>The Four Agreements: A Practical Guide to Personal Freedom by Miguel Ruiz</td></tr><tr><td>One Fish, Two Fish, Red Fish, Blue Fish by Dr. Seuss</td></tr><tr><td>Watchers by Dean Koontz</td></tr><tr><td>Fifty Shades Trilogy (Fifty Shades, #1-3) by E.L. James</td></tr><tr><td>The Joy of Cooking by Irma S. Rombauer, Marion Rombauer Becker, Ethan Becker</td></tr><tr><td>The Complete Anne of Green Gables Boxed Set (Anne of Green Gables, #1-8) by L.M. Montgomery</td></tr><tr><td>The Partner by John Grisham</td></tr><tr><td>Presumed Innocent by Scott Turow</td></tr><tr><td>Dr. Seuss's Green Eggs and Ham: For Soprano, Boy Soprano, and Orchestra by Robert Kapilow, Dr. Seuss</td></tr><tr><td>Inferno (The Divine Comedy #1) by Dante Alighieri, Anthony M. Esolen</td></tr><tr><td>The Girl Who Loved Tom Gordon by Stephen King</td></tr><tr><td>The Twilight Saga (Twilight, #1-4) by Stephenie Meyer, Ilyana Kadushin, Matt Walters</td></tr><tr><td>The Secret Keeper by Kate Morton</td></tr><tr><td>Better Homes and Gardens New Cook Book   by Better Homes and Gardens</td></tr><tr><td>Reached (Matched, #3) by Ally Condie</td></tr><tr><td>The Testament by John Grisham</td></tr><tr><td>90 Minutes in Heaven: A True Story of Death and Life by Don Piper, Cecil Murphey</td></tr><tr><td>Sam's Letters to Jennifer by James Patterson</td></tr><tr><td>Little Earthquakes by Jennifer Weiner</td></tr><tr><td>Lullaby by Chuck Palahniuk</td></tr><tr><td>The English Patient by Michael Ondaatje</td></tr><tr><td>Warm Bodies (Warm Bodies, #1) by Isaac Marion</td></tr><tr><td>Cold Sassy Tree by Olive Ann Burns</td></tr><tr><td>Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe, #1) by Benjamin Alire Sáenz</td></tr><tr><td>Summer Sisters by Judy Blume</td></tr><tr><td>A Scandal in Bohemia (The Adventures of Sherlock Holmes, #1) by Ronald Holt, Arthur Conan Doyle</td></tr><tr><td>The Brethren by John Grisham</td></tr><tr><td>The Case for Christ by Lee Strobel</td></tr><tr><td>The Complete Sherlock Holmes, Vol 2 by Arthur Conan Doyle, Kyle Freeman</td></tr><tr><td>The Pilgrim's Progress by John Bunyan</td></tr><tr><td>Janet Evanovich Three and Four Two-Book Set (Stephanie Plum, #3-4) by Janet Evanovich</td></tr><tr><td>Magician's Gambit (The Belgariad, #3) by David Eddings</td></tr><tr><td>Keeping Faith by Jodi Picoult</td></tr><tr><td>Ham on Rye by Charles Bukowski</td></tr><tr><td>Emotional Intelligence 2.0 by Travis Bradberry, Jean Greaves, Patrick Lencioni</td></tr><tr><td>Make Way for Ducklings by Robert McCloskey</td></tr><tr><td>On the Banks of Plum Creek  (Little House, #4) by Laura Ingalls Wilder, Garth Williams</td></tr><tr><td>PostSecret: Extraordinary Confessions from Ordinary Lives (PostSecret) by Frank Warren</td></tr><tr><td>The Borrowers (The Borrowers, #1) by Mary Norton, Beth Krush, Joe Krush</td ...

-- %% [markdown]
-- 9\. Revisit question 7 using ISNULL instead of COALESCE.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:

SELECT CONCAT(title + ' by ' + authors, ' by ' + authors), ISNULL(language_code,"") AS book_auth_lang
FROM BooksDB.dbo.books
--WHERE language_code IS NULL;
-- Out:
-- : Msg 1038, Level 15, State 4, Line 3
-- An object or column name is missing or empty. For SELECT INTO statements, verify each column has a name. For other statements, look for empty alias names. Aliases defined as "" or [] are not allowed. Change the alias to a valid name.
-- Total execution time: 00:00:00.054
